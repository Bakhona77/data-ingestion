# %%
df = spark.read.format("parquet") \
    .option("header", "true") \
    .load("s3://data-lake-landinglayer-dev/raw/customers/2026-04-14/")

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .save("s3://data-lake-bronzelayer-dev/raw/customers/")

# %%
# %sql
use catalog ingestion;
CREATE TABLE bronze.bronze_customer
USING DELTA
LOCATION 's3://data-lake-bronzelayer-dev/raw/customers/';
